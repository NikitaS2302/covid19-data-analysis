# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:\\Users\\KIIT\\Desktop\\tutedude\\DataScience\\data science\\covid19_Confirmed_dataset.csv")
data.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
df=data.drop(["Lat","Long"],axis=1,inplace=True)
data.head()
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
#aggregated dataset
corona_dataset_agg=data.groupby('Country/Region').sum()
corona_dataset_agg.head()
# Out:
#                Province/State  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# Country/Region
# Afghanistan                 0        0        0        0        0        0
# Albania                     0        0        0        0        0        0
# Algeria                     0        0        0        0        0        0
# Andorra                     0        0        0        0        0        0
# Angola                      0        0        0        0        0        0
#
#                 1/27/20  1/28/20  1/29/20  1/30/20  ...  4/21/20  4/22/20  \
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...     1092     1176
# Albania               0        0        0        0  ...      609      634
# Algeria               0        0        0        0  ...     2811     2910
# Andorra               0        0        0        0  ...      717      723
# ...

# %%
corona_dataset_agg.shape
# Out:
# (187, 101)

# %%
corona_dataset_aggregate=corona_dataset_agg.drop(['Province/State'],axis=1)
corona_dataset_aggregate.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/21/20  4/22/20  4/23/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1092     1176     1279
# Albania               0        0        0  ...      609      634      663
# Algeria               0        0        0  ...     2811     2910     3007
# Andorra               0        0        0  ...      717      723      723
# ...

# %%
corona_dataset_aggregate.shape
# Out:
# (187, 100)

# %%
#visualize data according to countries
corona_dataset_aggregate.loc['China'].plot()
corona_dataset_aggregate.loc['India'].plot()
corona_dataset_aggregate.loc['Spain'].plot()
plt.legend()
plt.show()

# %%
#calculate a good measure
corona_dataset_aggregate.loc['China'].plot()
plt.show()
print('Covid-19 in first 3 days:\n ')
corona_dataset_aggregate.loc['China'][:3].plot()
plt.show()
# Out:
# Covid-19 in first 3 days:

# %%
#calculate first derivative
corona_dataset_aggregate.loc['China'].diff().plot()
# Out:
# <Axes: >

# %%
#maximum infection rate
print('Maximum Infection Rate:\n')

print('CHINA: ',corona_dataset_aggregate.loc['China'].diff().max())
print('INDIA: ',corona_dataset_aggregate.loc['India'].diff().max())
print('Spain: ',corona_dataset_aggregate.loc['Spain'].diff().max())
# Out:
# maximum infection rate:
#
# CHINA:  15136.0
# INDIA:  1893.0
# Spain:  9630.0

# %%
countries=list(corona_dataset_aggregate.index)
max_infection_rate=[]
for c in countries:
    max_infection_rate.append(corona_dataset_aggregate.loc[c].diff().max())
corona_dataset_aggregate['Maximum_infection_rate']=max_infection_rate
corona_dataset_aggregate
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan               0        0        0        0        0        0
# Albania                   0        0        0        0        0        0
# Algeria                   0        0        0        0        0        0
# Andorra                   0        0        0        0        0        0
# Angola                    0        0        0        0        0        0
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza        0        0        0        0        0        0
# Western Sahara            0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
# ...

# %%
#create a new dataframe
corona_dataset=pd.DataFrame(corona_dataset_aggregate['Maximum_infection_rate'])
corona_dataset
# Out:
#                     Maximum_infection_rate
# Country/Region
# Afghanistan                          232.0
# Albania                               34.0
# Algeria                              199.0
# Andorra                               43.0
# Angola                                 5.0
# ...                                    ...
# West Bank and Gaza                    66.0
# Western Sahara                         4.0
# Yemen                                  5.0
# Zambia                                 9.0
# Zimbabwe                               8.0
#
# [187 rows x 1 columns]

# %%
happiness_report=pd.read_csv("C:\\Users\\KIIT\\Desktop\\tutedude\\DataScience\\data science\\worldwide_happiness_report.csv")
happiness_report.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
#drop cols
useless_cols=['Score','Overall rank','Perceptions of corruption','Generosity']
happiness=happiness_report.drop(useless_cols,axis=1,inplace=True)
happiness_report.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %%
happiness_report.set_index('Country or region',inplace=True)
happiness_report.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
#join dataset
corona_dataset.shape
# Out:
# (187, 1)

# %%
data=corona_dataset.join(happiness_report,how='inner')
data
# Out:
#              Maximum_infection_rate  GDP per capita  Social support  \
# Afghanistan                   232.0           0.350           0.517
# Albania                        34.0           0.947           0.848
# Algeria                       199.0           1.002           1.160
# Argentina                     291.0           1.092           1.432
# Armenia                       134.0           0.850           1.055
# ...                             ...             ...             ...
# Venezuela                      29.0           0.960           1.427
# Vietnam                        19.0           0.741           1.346
# Yemen                           5.0           0.287           1.163
# Zambia                          9.0           0.578           1.058
# Zimbabwe                        8.0           0.366           1.114
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# ...

# %%
data.corr()
# Out:
#                               Maximum_infection_rate  GDP per capita  \
# Maximum_infection_rate                      1.000000        0.250118
# GDP per capita                              0.250118        1.000000
# Social support                              0.191958        0.759468
# Healthy life expectancy                     0.289263        0.863062
# Freedom to make life choices                0.078196        0.394603
#
#                               Social support  Healthy life expectancy  \
# Maximum_infection_rate              0.191958                 0.289263
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# Maximum_infection_rate                            0.078196
# ...

# %%
data
# Out:
#              Maximum_infection_rate  GDP per capita  Social support  \
# Afghanistan                   232.0           0.350           0.517
# Albania                        34.0           0.947           0.848
# Algeria                       199.0           1.002           1.160
# Argentina                     291.0           1.092           1.432
# Armenia                       134.0           0.850           1.055
# ...                             ...             ...             ...
# Venezuela                      29.0           0.960           1.427
# Vietnam                        19.0           0.741           1.346
# Yemen                           5.0           0.287           1.163
# Zambia                          9.0           0.578           1.058
# Zimbabwe                        8.0           0.366           1.114
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# ...

# %%
x=data['GDP per capita']
y=data['Maximum_infection_rate']
sns.scatterplot(x=x,y=np.log(y)) #logscaling
# Out:
# <Axes: xlabel='GDP per capita', ylabel='Maximum_infection_rate'>

# %%
sns.regplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='GDP per capita', ylabel='Maximum_infection_rate'>

# %%
x=data['Social support']
y=data['Maximum_infection_rate']
sns.scatterplot(x=x,y=np.log(y)) #logscaling
# Out:
# <Axes: xlabel='Social support', ylabel='Maximum_infection_rate'>

# %%
sns.regplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Social support', ylabel='Maximum_infection_rate'>

# %%
x=data['Healthy life expectancy']
y=data['Maximum_infection_rate']
sns.scatterplot(x=x,y=np.log(y)) #logscaling
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='Maximum_infection_rate'>

# %%
sns.regplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='Maximum_infection_rate'>

# %%
x=data['Freedom to make life choices']
y=data['Maximum_infection_rate']
sns.scatterplot(x=x,y=np.log(y)) #logscaling
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='Maximum_infection_rate'>

# %%
sns.regplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='Maximum_infection_rate'>
